# %% [markdown]
# ## Práctica Machine Learning
# #### Clasificación de patrones técnicos

# %% [markdown]
# Este cuaderno incluye un script para el etiquetado de gráficas de velas, que son
# elegidas de forma aleatoria a partir de los datos diarios del IBEX35.
# Para más detalle consultar el enunciado de la práctica

# %% [markdown]
# Se requiere la instalación de mpl_finance

# %%
if self.tops == 0:
            days_between = 0
            return days_between
        tops = pd.Series(self.tops)
        returns = (self.datos_ventana.close[-1] / self.datos_ventana.close[tops.max()]) - 1
        if returns > 0:
            returns = 1
        if returns < 0:
            returns = 0
            
            
            
            if self.bottoms == 0:
            days_between = 0
            return days_between
        bottoms = pd.Series(self.bottoms)
        returns = (self.datos_ventana.close[-1] / self.datos_ventana.close[bottoms.max()]) - 1
        if returns > 0:
            returns = 1
        if returns < 0:
            returns = 0
        return returns

# %%
import pickle

# %%
with open('../data/benchmark_data.pkl', 'rb') as handle:
    bm = pickle.load(handle)

# %%
ibex = bm['ibex']

# %%
ibex.head()
# Out:
#               close     high      low     open          vol
# 2000-01-03  11610.0  11881.8  11574.4  11846.6   60107000.0
# 2000-01-04  11206.6  11530.0  11159.8  11499.5   62539000.0
# 2000-01-05  10863.1  11068.1  10824.9  11206.6   68153000.0
# 2000-01-07  11102.4  11137.9  10882.7  10963.4  144207000.0
# 2000-01-10  11173.3  11364.3  11120.6  11363.8  133817000.0

# %%
from mpl_finance import candlestick2_ohlc

# %% [markdown]
# *mpl_finance* es uan librería de python que permite la generación de gráficos
# de velas de forma sencilla.  A continuación se muestra un ejemplo. Primero se
# elige una ventana temporal y luego se pasan los datos de cada serie OHLC

# %%
windata = ibex.loc["2013-02-03":"2013-03-20"]
fig, ax = plt.subplots(figsize=(6,4))
_ = candlestick2_ohlc(ax, windata.open, windata.high,
                          windata.low, windata.close,
                          colorup='g', colordown='r', width=0.66, alpha=0.8)
plt.show()

# %% [markdown]
# Si se necesita guardar el gráfico

# %% [markdown]
# ___

# %% [markdown]
# #### Bucle de Etiquetado
# El siguiente código es un bucle que:
# 1. Elige una posición aleatoria de la serie para crear una ventana de 30 días
# 2. Dibuja el gráfico de velas
# 3. Pide al usuario que introduzca un número para etiquetar la gráfica.
#
# Primero hay que elegir el tamaño de la ventana y el número de ejemplos que se quieren generar.
# Se tiene la opción de descartar algún ejemplo si no se quiere incluir (ej. posiblemente ambiguo)

# %%
window = 30
n = 200

# %%
# etiquetas = np.zeros(n)
idfechas = np.zeros(n)
etiquetas = np.zeros(n)
for i in range(n):
    idx = np.random.randint(0, ibex.shape[0] - window)
    idfechas[i] = idx
    windata = ibex.iloc[idx:idx+window]
    fig, ax = plt.subplots(figsize=(6,4))
    _ = candlestick2_ohlc(ax, windata.open, windata.high,
                         windata.low, windata.close,
                         colorup='g', colordown='r', width=0.66, alpha=0.8)
    plt.show()
    print(f'Ejemplo {i+1} de {n}')
    print("Etiquete la siguiete grafica como:")
    print(" [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo")
    opcion_usuario = input()
    if opcion_usuario >= '0' and opcion_usuario <= '2':
        etiquetas[i] = opcion_usuario   
    else:
        print('Error en la opción introducida. Ejemplo descartado')
        etiquetas[i] = 2
# Out:
# Ejemplo 1 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 2 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 3 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 4 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 5 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 6 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 7 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 8 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 9 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 10 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 11 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 12 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 13 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 14 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 15 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 16 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 17 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 18 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 19 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 20 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 21 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 22 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 23 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 24 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 25 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 26 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 27 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 28 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 29 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 30 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 31 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 32 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 33 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 34 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 35 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 36 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 37 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 38 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 39 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 40 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 41 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 42 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 43 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 44 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 45 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 46 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 47 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 48 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 49 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 50 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 51 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 52 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 53 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 54 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 55 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  4
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 56 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 57 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 58 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 59 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 60 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 61 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 62 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 63 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 64 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 65 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 66 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 67 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 68 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  1
# Ejemplo 69 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  4
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 70 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 71 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 72 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  4
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 73 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 74 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 75 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 76 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 77 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 78 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 79 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 80 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 81 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 82 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 83 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 84 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 85 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 86 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 87 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 88 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 89 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 90 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 91 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 92 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 93 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 94 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 95 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 96 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 97 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 98 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 99 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 100 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 101 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 102 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 103 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 104 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 105 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 106 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 107 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 108 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 109 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 110 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 111 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 112 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 113 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 114 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 115 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 116 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 117 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 118 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 119 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 120 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 121 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 122 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 123 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 124 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 125 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  4
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 126 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 127 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 128 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 129 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 130 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 131 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 132 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 133 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 134 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 135 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 136 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 137 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 138 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 139 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 140 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 141 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  4
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 142 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 143 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  4
# Error en la opción introducida. Ejemplo descartado
# Ejemplo 144 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 145 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 146 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 147 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 148 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 149 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 150 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 151 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 152 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 153 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 154 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 155 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 156 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 157 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 158 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 159 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 160 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 161 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 162 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 163 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 164 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 165 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 166 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 167 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 168 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 169 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 170 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 171 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 172 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 173 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 174 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 175 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 176 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 177 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 178 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 179 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 180 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 181 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 182 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 183 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 184 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 185 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 186 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 187 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 188 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 189 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 190 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 191 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 192 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 193 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 194 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 195 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 196 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 197 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 198 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 199 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0
# Ejemplo 200 de 200
# Etiquete la siguiete grafica como:
#  [1] Doble suelo, [4] doble_techo, [0] Descartar ejemplo
#  0

# %%
labels = pd.Series(etiquetas, index=ibex.index[idfechas.astype(np.int)])
# Out:
# <ipython-input-36-97bbcaa88cd7>:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   labels = pd.Series(etiquetas, index=ibex.index[idfechas.astype(np.int)])

# %%
ejemplos.append(labels)

# %%
for i in range(len(ejemplos)):
    if i == 0:
        data = ejemplos[i]
    else:    
        data = pd.concat([data, ejemplos[i]])

# %%
data[data == 1]
# Out:
# 2004-12-28    1.0
# 2013-04-03    1.0
# 2014-01-13    1.0
# 2007-02-08    1.0
# 2014-06-19    1.0
# 2014-01-17    1.0
# 2013-03-19    1.0
# 2007-02-22    1.0
# 2007-02-16    1.0
# 2012-09-07    1.0
# 2004-03-02    1.0
# 2012-09-19    1.0
# 2016-06-17    1.0
# dtype: float64

# %%
data.to_csv('datos.csv')

# %% [markdown]
# Descartamos las etiquetas descartadas

# %%
data = pd.read_csv('datos.csv')
data.columns = ['fechas','etiquetas']

# %%
data[data['etiquetas'] == 1]
# Out:
#           fechas  etiquetas
# 17    2004-12-28        1.0
# 196   2013-04-03        1.0
# 261   2014-01-13        1.0
# 285   2007-02-08        1.0
# 306   2014-06-19        1.0
# 379   2014-01-17        1.0
# 563   2013-03-19        1.0
# 615   2007-02-22        1.0
# 627   2007-02-16        1.0
# 825   2012-09-07        1.0
# 837   2004-03-02        1.0
# 838   2012-09-19        1.0
# 1067  2016-06-17        1.0

# %%
doble_suelo_labels = data[data['etiquetas'] == 1]
doble_techo_labels = data[data['etiquetas'] == 2]

# %%
ejemplos_doble_suelo = pd.read_csv('ejemplos_doble_suelo.csv')
ejemplos_doble_suelo = ejemplos_doble_suelo.iloc[:,1:]
ejemplos_doble_suelo = pd.concat([ejemplos_doble_suelo, doble_suelo_labels])
ejemplos_doble_suelo.to_csv('ejemplos_doble_suelo.csv')

ejemplos_doble_techo = pd.read_csv('ejemplos_doble_techo.csv')
ejemplos_doble_techo = ejemplos_doble_techo.iloc[:,1:]
ejemplos_doble_techo = pd.concat([ejemplos_doble_techo, doble_techo_labels])
ejemplos_doble_techo.to_csv('ejemplos_doble_techo.csv')

# %%
len(ejemplos_doble_techo)

# %%
len(ejemplos_doble_suelo)

# %% [markdown]
# Guardamos el fichero en CSV para su posterior procesamiento

# %%
doble_suelo_labels.to_csv('ejemplos_doble_suelo.csv')

# %%
total_suelo = len(pd.read_csv('ejemplos_doble_suelo.csv'))
x = 6
for numero in range(2,x): 
    total_suelo += len(pd.read_csv(f'ejemplos_doble_suelo_{numero}.csv'))
print(total_suelo)

# %%
x = 5
total_techo = 0
for numero in range(1,x): 
    total_techo += len(pd.read_csv(f'ejemplos_doble_techo_{numero}.csv'))
print(total_techo)

# %%
a = pd.read_csv('ejemplos_doble_suelo.csv')
b = pd.read_csv('ejemplos_doble_suelo_2.csv')
c = pd.read_csv('ejemplos_doble_suelo_3.csv')
d = pd.read_csv('ejemplos_doble_suelo_4.csv')
e = pd.read_csv('ejemplos_doble_suelo_5.csv')

# %%
frames = [a, b, c, d, e]
doble_suelo = pd.concat(frames)

# %%
doble_suelo

# %%
pd.read_csv('ejemplos_doble_suelo.csv')
